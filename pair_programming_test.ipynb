# %%
import pair_programming as pp

# %%
#Test 1
pp.meters(2, 4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Test 1
# ----> 2 pp.meters(2, 4)
#
# File ~/Desktop/work/classes/GPGN268/mattson-pair-programming/pair_programming.py:6, in meters(feet, inches)
#       5 def meters(feet, inches):
# ----> 6     if feet.isalpha() == True or inches.isalpha() == True: #check for alpha values
#       7         print('Please input a number for feet and inches')
#       8         feet = input('feet: ')
#
# AttributeError: 'int' object has no attribute 'isalpha'

# %%
#Test 2
pp.meters(4.92137, 2.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 #Test 2
# ----> 2 pp.meters(4.92137, 2.5)
#
# File ~/Desktop/work/classes/GPGN268/mattson-pair-programming/pair_programming.py:6, in meters(feet, inches)
#       5 def meters(feet, inches):
# ----> 6     if feet.isalpha() == True or inches.isalpha() == True: #check for alpha values
#       7         print('Please input a number for feet and inches')
#       8         feet = input('feet: ')
#
# AttributeError: 'float' object has no attribute 'isalpha'
